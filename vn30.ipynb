# %%
import requests
import math 

from io import BytesIO

import vnquant.data as dt
import pandas as pd

# %%
def get_data(ticker):
    """
    Hàm dùng để lấy data từ API của cafeF thông qua vnquant
    ticker là mã chứng khoán
    Data trả về là dữ liệu lịch sử về giá của cổ phiếu
    """
    loader = dt.DataLoader(
        symbols=ticker, 
        start="2022-01-01", 
        end="2022-06-30", 
        minimal=False, 
        data_source="cafe"
    )

    data = loader.download()

    return data

# %%
def get_general_data(url):
    """
    Hàm dùng để lấy data từ file google sheet
    url là link của sheet
    """
    r = requests.get(url)
    data = r.content
    return pd.read_csv(BytesIO(data), index_col=0, thousands=',').reset_index()

# %%
general_df = get_general_data(
    "https://docs.google.com/spreadsheets/d/e/"\
    "2PACX-1vQmN9UGZ1PZpBkNtsXRGU4ThR0cMrNkLamoNO20hqbcf1DWPgQWE6zOl2htjdu34xawP25dheCyXMug/"\
    "pub?gid=12001416&single=true&output=csv"
)

# %%
general_df
# Out:
#                     industry                                        company  \
# 0                    Dịch vụ   Công ty Cổ phần Nước – Môi trường Bình Dương
# 1                    Dịch vụ     Công ty Cổ phần In sách giáo khoa Hòa Phát
# 2                    Dịch vụ           Công ty Cổ phần Đầu tư Apax Holdings
# 3                    Dịch vụ  Tổng Công ty Cổ phần Dịch vụ Tổng hợp Dầu khí
# 4                    Dịch vụ      Công ty Cổ phần Vàng bạc Đá quý Phú Nhuận
# ..                       ...                                            ...
# 118  Bất động sản - Xây dựng                   Công ty Cổ phần Thaiholdings
# 119  Bất động sản - Xây dựng                  Tổng Công ty Viglacera - CTCP
# 120  Bất động sản - Xây dựng                       Công ty cổ phần Vinhomes
# 121  Bất động sản - Xây dựng            Tập đoàn Vingroup - Công ty Cổ phần
# 122  Bất động sản - Xây dựng                  Công ty Cổ phần Vincom Retail
#
#     ticker  market_cap
# 0      BWE     9858.21
# 1      HTP     3314.16
# 2      IBC     1650.54
# 3      PET     3273.11
# 4      PNJ    31071.39
# ..     ...         ...
# 118    THD    19845.00
# 119    VGC    23717.72
# 120    VHM   267358.16
# 121    VIC   277524.85
# 122    VRE    65101.92
#
# [123 rows x 4 columns]

# %%
# Lấy ra một list các mã chứng khoán trong sheet, để từ đó call API cafeF để lấy dữ liệu lịch sử
list_tickers = list(general_df["ticker"])

# %%
len(list_tickers)
# Out:
# 123

# %%
df = get_data(ticker=list_tickers)
# Out:
# 2022-07-23 16:28:03,633 : INFO : NumExpr defaulting to 4 threads.
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:05,409 : INFO : data BWE from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:07,143 : INFO : data HTP from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:08,839 : INFO : data IBC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:10,482 : INFO : data PET from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:12,247 : INFO : data PNJ from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:14,073 : INFO : data PTB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:16,002 : INFO : data PVI from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:17,787 : INFO : data SCS from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:19,663 : INFO : data SGN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:21,456 : INFO : data SVC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:22,997 : INFO : data TDM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:24,629 : INFO : data BHN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:26,461 : INFO : data GIL from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:27,237 : INFO : data GTN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:30,617 : INFO : data KDC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:33,230 : INFO : data MSH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:36,681 : INFO : data RAL from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:39,650 : INFO : data SAB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:42,588 : INFO : data SHI from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:44,263 : INFO : data STK from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:46,133 : INFO : data TCM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:48,053 : INFO : data TLG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:52,064 : INFO : data TNG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:56,060 : INFO : data TTF from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:28:58,137 : INFO : data VCF from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:00,064 : INFO : data VNM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:01,935 : INFO : data CHP from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:03,846 : INFO : data DTK from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:05,528 : INFO : data GAS from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:07,215 : INFO : data GEG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:08,985 : INFO : data NT2 from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:10,679 : INFO : data PGD from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:12,234 : INFO : data PGV from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:13,845 : INFO : data PLX from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:16,070 : INFO : data POW from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:19,708 : INFO : data PPC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:22,139 : INFO : data PVD from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:24,852 : INFO : data PVS from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:27,237 : INFO : data PVT from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:29,584 : INFO : data TMP from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:31,943 : INFO : data VSH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:34,208 : INFO : data HPG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:36,239 : INFO : data DGC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:38,123 : INFO : data HSG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:39,711 : INFO : data VIF from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:42,006 : INFO : data NKG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:44,503 : INFO : data DHC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:46,651 : INFO : data AAA from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:48,823 : INFO : data APH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:51,072 : INFO : data VPG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:53,004 : INFO : data POM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:55,134 : INFO : data CSV from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:29:58,472 : INFO : data PLC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:00,695 : INFO : data MVB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:02,723 : INFO : data TDP from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:04,643 : INFO : data ANV from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:06,999 : INFO : data BAF from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:10,680 : INFO : data DBC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:13,083 : INFO : data DCM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:15,483 : INFO : data DPM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:18,078 : INFO : data DPR from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:20,324 : INFO : data FMC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:22,492 : INFO : data GVR from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:24,465 : INFO : data HNG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:27,019 : INFO : data IDI from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:28,900 : INFO : data PAN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:30,770 : INFO : data SBT from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:33,111 : INFO : data VHC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:35,291 : INFO : data ACB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:38,032 : INFO : data BID from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:40,935 : INFO : data BVH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:43,291 : INFO : data CTG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:45,477 : INFO : data EIB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:47,474 : INFO : data HDB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:49,522 : INFO : data MBB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:51,495 : INFO : data MSN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:53,379 : INFO : data SHB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:55,516 : INFO : data SSB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:30:57,673 : INFO : data STB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:00,045 : INFO : data TCB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:02,337 : INFO : data TPB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:04,600 : INFO : data VCB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:06,579 : INFO : data VIB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:09,027 : INFO : data VPB from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:11,329 : INFO : data THI from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:13,787 : INFO : data SGT from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:16,655 : INFO : data MWG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:18,489 : INFO : data MBG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:20,683 : INFO : data GEX from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:23,462 : INFO : data FRT from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:25,985 : INFO : data FPT from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:28,269 : INFO : data ELC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:30,757 : INFO : data DGW from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:35,566 : INFO : data CMG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:38,173 : INFO : data VJC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:40,446 : INFO : data HVN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:42,813 : INFO : data GMD from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:45,167 : INFO : data TMS from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:47,491 : INFO : data LGC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:49,585 : INFO : data HHV from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:51,924 : INFO : data PHP from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:54,619 : INFO : data VSC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:56,660 : INFO : data HAH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:31:59,014 : INFO : data CII from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:00,800 : INFO : data DRC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:02,737 : INFO : data CAV from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:04,588 : INFO : data STG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:06,392 : INFO : data CDN from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:08,232 : INFO : data AST from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:09,890 : INFO : data BCM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:12,108 : INFO : data DIG from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:14,277 : INFO : data IDC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:16,501 : INFO : data KBC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:18,876 : INFO : data KDH from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:21,398 : INFO : data KSF from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:23,404 : INFO : data NVL from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:25,676 : INFO : data PDR from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:28,190 : INFO : data REE from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:29,980 : INFO : data THD from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:32,454 : INFO : data VGC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:34,640 : INFO : data VHM from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:37,053 : INFO : data VIC from 2022-01-01 to 2022-06-30 have already cloned!
# /Users/phamcuong/opt/miniconda3/lib/python3.8/site-packages/vnquant-0.0.3-py3.8.egg/vnquant/data/dataloader.py:256: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-07-23 16:32:39,624 : INFO : data VRE from 2022-01-01 to 2022-06-30 have already cloned!

# %%
stacked_df = df[["close"]].stack().reset_index()

# %%
# Dữ liệu giá đóng cửa của các cổ phiếu nhưng được transform thành dạng dọc (thay vì dạng ngang như ban đầu)
stacked_df
# Out:
# Attributes       date Symbols  close
# 0          2022-01-04     AAA  20.70
# 1          2022-01-04     ACB  34.40
# 2          2022-01-04     ANV  34.10
# 3          2022-01-04     APH  37.65
# 4          2022-01-04     AST  53.20
# ...               ...     ...    ...
# 14635      2022-06-30     VPB  29.00
# 14636      2022-06-30     VPG  29.00
# 14637      2022-06-30     VRE  28.55
# 14638      2022-06-30     VSC  41.65
# 14639      2022-06-30     VSH  45.00
#
# [14640 rows x 3 columns]

# %%
# JOIN stacked_df với df ban đầu để lấy data về market size cho từng cổ phiếu
merged_df = pd.merge(stacked_df, general_df, how="left", left_on='Symbols', right_on='ticker')

# %%
# Lấy ngày, tên cổ phiếu, ngành, market cap, và giá đóng cửa
merged_df = merged_df[["date", "ticker", "industry", "market_cap", "close"]]

# %%
# Pivot merged_df để tính toán phân trăm thay đổi giá cổ phiếu giữa ngày thứ X và ngày đầu tiên
pivot_df = merged_df.pivot(index=["ticker", "industry", "market_cap"], columns="date", values="close").reset_index()

# %%
pivot_df
# Out:
# date ticker                  industry  market_cap  2022-01-04 00:00:00  \
# 0       AAA                  Vật liệu     3737.67                20.70
# 1       ACB                 Tài chính    81227.31                34.40
# 2       ANV               Nông nghiệp     6817.54                34.10
# 3       APH                  Vật liệu     2975.39                37.65
# 4       AST  Công nghiệp - Hàng không     2605.50                53.20
# ..      ...                       ...         ...                  ...
# 118     VPB                 Tài chính   128461.18                36.05
# 119     VPG                  Vật liệu     2341.79                57.10
# 120     VRE   Bất động sản - Xây dựng    65101.92                31.15
# 121     VSC  Công nghiệp - Hàng không     5032.71                43.50
# 122     VSH                Năng lượng    10394.61                28.80
#
# date  2022-01-05 00:00:00  2022-01-06 00:00:00  2022-01-07 00:00:00  \
# 0                   20.95                22.40                22.80
# 1                   33.70                33.75                33.30
# 2                   35.85                35.40                35.30
# 3                   37.15                37.25                37.00
# 4                   53.50                53.50                53.00
# ..                    ...                  ...                  ...
# 118                 35.50                35.15                34.60
# 119                 56.10                55.50                55.00
# 120                 33.30                35.60                34.75
# 121                 43.00                42.70                43.30
# 122                 28.80                28.85                28.80
#
# date  2022-01-10 00:00:00  2022-01-11 00:00:00  2022-01-12 00:00:00  ...  \
# 0                   21.25                20.00                19.60  ...
# 1                   33.00                32.75                33.10  ...
# 2                   33.45                32.00                31.15  ...
# 3                   35.95                34.50                34.70  ...
# 4                   53.30                52.70                52.50  ...
# ..                    ...                  ...                  ...  ...
# 118                 34.40                34.30                35.40  ...
# 119                 53.00                53.20                53.00  ...
# 120                 35.00                34.20                36.00  ...
# 121                 42.70                41.70                40.40  ...
# 122                 28.60                28.70                28.70  ...
#
# date  2022-06-17 00:00:00  2022-06-20 00:00:00  2022-06-21 00:00:00  \
# 0                   11.00                10.30                 11.0
# 1                   23.10                22.90                 23.0
# 2                   63.70                61.70                 57.4
# 3                   11.65                10.85                 10.7
# 4                   57.90                57.70                 56.0
# ..                    ...                  ...                  ...
# 118                 27.90                27.10                 27.2
# 119                 31.75                29.55                 27.5
# 120                 29.35                28.70                 28.0
# 121                 50.20                47.50                 45.6
# 122                 46.35                46.80                 45.0
#
# date  2022-06-22 00:00:00  2022-06-23 00:00:00  2022-06-24 00:00:00  \
# 0                   11.35                11.70                11.80
# 1                   23.75                23.75                23.80
# 2                   53.40                57.10                57.00
# 3                   11.40                11.65                12.20
# 4                   56.00                56.70                56.10
# ..                    ...                  ...                  ...
# 118                 28.40                28.45                28.15
# 119                 28.80                29.75                30.15
# 120                 28.50                28.05                27.55
# 121                 42.45                45.30                44.30
# 122                 41.85                43.50                43.80
#
# date  2022-06-27 00:00:00  2022-06-28 00:00:00  2022-06-29 00:00:00  \
# 0                   11.90                12.00                11.85
# 1                   23.95                24.50                24.20
# 2                   57.50                53.50                56.00
# 3                   12.45                12.80                12.80
# 4                   58.50                58.70                58.30
# ..                    ...                  ...                  ...
# 118                 28.90                30.00                30.00
# 119                 30.35                30.25                29.70
# 120                 28.75                28.85                28.45
# 121                 44.90                44.00                42.20
# 122                 43.90                44.50                44.90
#
# date  2022-06-30 00:00:00
# 0                   11.30
# 1                   24.00
# 2                   53.00
# 3                   12.00
# 4                   57.90
# ..                    ...
# 118                 29.00
# 119                 29.00
# 120                 28.55
# 121                 41.65
# 122                 45.00
#
# [123 rows x 123 columns]

# %%
# Tạo một df mới lấy từ 3 cột của pivot_df, dùng df này để thêm % thay đổi của các ngày
final_result = pivot_df[["ticker", "industry", "market_cap"]]

# %%
arr = []
# Cleaning tên cột của pivot_df, vì tên cột dạng datetime đang thừa phần 00:00:00
for column in pivot_df:
    arr.append(str(column).split(" ")[0])

# %%
arr
# Out:
# ['ticker',
#  'industry',
#  'market_cap',
#  '2022-01-04',
#  '2022-01-05',
#  '2022-01-06',
#  '2022-01-07',
#  '2022-01-10',
#  '2022-01-11',
#  '2022-01-12',
#  '2022-01-13',
#  '2022-01-14',
#  '2022-01-17',
#  '2022-01-18',
#  '2022-01-19',
#  '2022-01-20',
#  '2022-01-21',
#  '2022-01-24',
#  '2022-01-25',
#  '2022-01-26',
#  '2022-01-27',
#  '2022-01-28',
#  '2022-02-07',
#  '2022-02-08',
#  '2022-02-09',
#  '2022-02-10',
#  '2022-02-11',
#  '2022-02-14',
#  '2022-02-15',
#  '2022-02-16',
#  '2022-02-17',
#  '2022-02-18',
#  '2022-02-21',
#  '2022-02-22',
#  '2022-02-23',
#  '2022-02-24',
#  '2022-02-25',
#  '2022-02-28',
#  '2022-03-01',
#  '2022-03-02',
#  '2022-03-03',
#  '2022-03-04',
#  '2022-03-07',
#  '2022-03-08',
#  '2022-03-09',
#  '2022-03-10',
#  '2022-03-11',
#  '2022-03-14',
#  '2022-03-15',
#  '2022-03-16',
#  '2022-03-17',
#  '2022-03-18',
#  '2022-03-21',
#  '2022-03-22',
#  '2022-03-23',
#  '2022-03-24',
#  '2022-03-25',
#  '2022-03-28',
#  '2022-03-29',
#  '2022-03-30',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-04',
#  '2022-04-05',
#  '2022-04-06',
#  '2022-04-07',
#  '2022-04-08',
#  '2022-04-12',
#  '2022-04-13',
#  '2022-04-14',
#  '2022-04-15',
#  '2022-04-18',
#  '2022-04-19',
#  '2022-04-20',
#  '2022-04-21',
#  '2022-04-22',
#  '2022-04-25',
#  '2022-04-26',
#  '2022-04-27',
#  '2022-04-28',
#  '2022-04-29',
#  '2022-05-04',
#  '2022-05-05',
#  '2022-05-06',
#  '2022-05-09',
#  '2022-05-10',
#  '2022-05-11',
#  '2022-05-12',
#  '2022-05-13',
#  '2022-05-16',
#  '2022-05-17',
#  '2022-05-18',
#  '2022-05-19',
#  '2022-05-20',
#  '2022-05-23',
#  '2022-05-24',
#  '2022-05-25',
#  '2022-05-26',
#  '2022-05-27',
#  '2022-05-30',
#  '2022-05-31',
#  '2022-06-01',
#  '2022-06-02',
#  '2022-06-03',
#  '2022-06-06',
#  '2022-06-07',
#  '2022-06-08',
#  '2022-06-09',
#  '2022-06-10',
#  '2022-06-13',
#  '2022-06-14',
#  '2022-06-15',
#  '2022-06-16',
#  '2022-06-17',
#  '2022-06-20',
#  '2022-06-21',
#  '2022-06-22',
#  '2022-06-23',
#  '2022-06-24',
#  '2022-06-27',
#  '2022-06-28',
#  '2022-06-29',
#  '2022-06-30']

# %%
# Đổi tên cột của pivot_df với những cột vừa thay 
pivot_df.columns = arr

# %%
# Ngày đầu tiên là mốc thời gian để so sánh giá, vì thế ngày này, mức độ thay đổi mặc định là 0
final_result[arr[3]] = 0
# Out:
# <ipython-input-19-36f657fb020d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_result[arr[3]] = 0

# %%
# Tính toán sự thay đổi của các ngày so với ngày đầu tiên
for i in range(3, len(arr)):
    final_result[arr[i]] = round((pivot_df[arr[i]] - pivot_df[arr[3]]) / pivot_df[arr[3]] * 100, 2)
# Out:
# <ipython-input-20-b76f10c022ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_result[arr[i]] = round((pivot_df[arr[i]] - pivot_df[arr[3]]) / pivot_df[arr[3]] * 100, 2)

# %%
final_result
# Out:
# date ticker                  industry  market_cap  2022-01-04  2022-01-05  \
# 0       AAA                  Vật liệu     3737.67         0.0        1.21
# 1       ACB                 Tài chính    81227.31         0.0       -2.03
# 2       ANV               Nông nghiệp     6817.54         0.0        5.13
# 3       APH                  Vật liệu     2975.39         0.0       -1.33
# 4       AST  Công nghiệp - Hàng không     2605.50         0.0        0.56
# ..      ...                       ...         ...         ...         ...
# 118     VPB                 Tài chính   128461.18         0.0       -1.53
# 119     VPG                  Vật liệu     2341.79         0.0       -1.75
# 120     VRE   Bất động sản - Xây dựng    65101.92         0.0        6.90
# 121     VSC  Công nghiệp - Hàng không     5032.71         0.0       -1.15
# 122     VSH                Năng lượng    10394.61         0.0        0.00
#
# date  2022-01-06  2022-01-07  2022-01-10  2022-01-11  2022-01-12  ...  \
# 0           8.21       10.14        2.66       -3.38       -5.31  ...
# 1          -1.89       -3.20       -4.07       -4.80       -3.78  ...
# 2           3.81        3.52       -1.91       -6.16       -8.65  ...
# 3          -1.06       -1.73       -4.52       -8.37       -7.84  ...
# 4           0.56       -0.38        0.19       -0.94       -1.32  ...
# ..           ...         ...         ...         ...         ...  ...
# 118        -2.50       -4.02       -4.58       -4.85       -1.80  ...
# 119        -2.80       -3.68       -7.18       -6.83       -7.18  ...
# 120        14.29       11.56       12.36        9.79       15.57  ...
# 121        -1.84       -0.46       -1.84       -4.14       -7.13  ...
# 122         0.17        0.00       -0.69       -0.35       -0.35  ...
#
# date  2022-06-17  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# 0         -46.86      -50.24      -46.86      -45.17      -43.48      -43.00
# 1         -32.85      -33.43      -33.14      -30.96      -30.96      -30.81
# 2          86.80       80.94       68.33       56.60       67.45       67.16
# 3         -69.06      -71.18      -71.58      -69.72      -69.06      -67.60
# 4           8.83        8.46        5.26        5.26        6.58        5.45
# ..           ...         ...         ...         ...         ...         ...
# 118       -22.61      -24.83      -24.55      -21.22      -21.08      -21.91
# 119       -44.40      -48.25      -51.84      -49.56      -47.90      -47.20
# 120        -5.78       -7.87      -10.11       -8.51       -9.95      -11.56
# 121        15.40        9.20        4.83       -2.41        4.14        1.84
# 122        60.94       62.50       56.25       45.31       51.04       52.08
#
# date  2022-06-27  2022-06-28  2022-06-29  2022-06-30
# 0         -42.51      -42.03      -42.75      -45.41
# 1         -30.38      -28.78      -29.65      -30.23
# 2          68.62       56.89       64.22       55.43
# 3         -66.93      -66.00      -66.00      -68.13
# 4           9.96       10.34        9.59        8.83
# ..           ...         ...         ...         ...
# 118       -19.83      -16.78      -16.78      -19.56
# 119       -46.85      -47.02      -47.99      -49.21
# 120        -7.70       -7.38       -8.67       -8.35
# 121         3.22        1.15       -2.99       -4.25
# 122        52.43       54.51       55.90       56.25
#
# [123 rows x 123 columns]

# %%
# Fill các giá trị trống NAN bằng 0
final_result = final_result.fillna(0)

# %%
final_result
# Out:
# date ticker                  industry  market_cap  2022-01-04  2022-01-05  \
# 0       AAA                  Vật liệu     3737.67         0.0        1.21
# 1       ACB                 Tài chính    81227.31         0.0       -2.03
# 2       ANV               Nông nghiệp     6817.54         0.0        5.13
# 3       APH                  Vật liệu     2975.39         0.0       -1.33
# 4       AST  Công nghiệp - Hàng không     2605.50         0.0        0.56
# ..      ...                       ...         ...         ...         ...
# 118     VPB                 Tài chính   128461.18         0.0       -1.53
# 119     VPG                  Vật liệu     2341.79         0.0       -1.75
# 120     VRE   Bất động sản - Xây dựng    65101.92         0.0        6.90
# 121     VSC  Công nghiệp - Hàng không     5032.71         0.0       -1.15
# 122     VSH                Năng lượng    10394.61         0.0        0.00
#
# date  2022-01-06  2022-01-07  2022-01-10  2022-01-11  2022-01-12  ...  \
# 0           8.21       10.14        2.66       -3.38       -5.31  ...
# 1          -1.89       -3.20       -4.07       -4.80       -3.78  ...
# 2           3.81        3.52       -1.91       -6.16       -8.65  ...
# 3          -1.06       -1.73       -4.52       -8.37       -7.84  ...
# 4           0.56       -0.38        0.19       -0.94       -1.32  ...
# ..           ...         ...         ...         ...         ...  ...
# 118        -2.50       -4.02       -4.58       -4.85       -1.80  ...
# 119        -2.80       -3.68       -7.18       -6.83       -7.18  ...
# 120        14.29       11.56       12.36        9.79       15.57  ...
# 121        -1.84       -0.46       -1.84       -4.14       -7.13  ...
# 122         0.17        0.00       -0.69       -0.35       -0.35  ...
#
# date  2022-06-17  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# 0         -46.86      -50.24      -46.86      -45.17      -43.48      -43.00
# 1         -32.85      -33.43      -33.14      -30.96      -30.96      -30.81
# 2          86.80       80.94       68.33       56.60       67.45       67.16
# 3         -69.06      -71.18      -71.58      -69.72      -69.06      -67.60
# 4           8.83        8.46        5.26        5.26        6.58        5.45
# ..           ...         ...         ...         ...         ...         ...
# 118       -22.61      -24.83      -24.55      -21.22      -21.08      -21.91
# 119       -44.40      -48.25      -51.84      -49.56      -47.90      -47.20
# 120        -5.78       -7.87      -10.11       -8.51       -9.95      -11.56
# 121        15.40        9.20        4.83       -2.41        4.14        1.84
# 122        60.94       62.50       56.25       45.31       51.04       52.08
#
# date  2022-06-27  2022-06-28  2022-06-29  2022-06-30
# 0         -42.51      -42.03      -42.75      -45.41
# 1         -30.38      -28.78      -29.65      -30.23
# 2          68.62       56.89       64.22       55.43
# 3         -66.93      -66.00      -66.00      -68.13
# 4           9.96       10.34        9.59        8.83
# ..           ...         ...         ...         ...
# 118       -19.83      -16.78      -16.78      -19.56
# 119       -46.85      -47.02      -47.99      -49.21
# 120        -7.70       -7.38       -8.67       -8.35
# 121         3.22        1.15       -2.99       -4.25
# 122        52.43       54.51       55.90       56.25
#
# [123 rows x 123 columns]

# %%
# Export final data ra file csv
final_result.to_csv("data.csv")
